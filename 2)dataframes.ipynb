# %%
import numpy as np
import pandas as pd

# %%
Creation of Dataframes

# %%
data = {
    "Name" : ["loki","rawat","lucky"],
    "Age"  : [19,20,25],
    "city" : ["new york","california","paris"],
    "salary" : [10000000,30000000,5000000000]
}
pd.DataFrame(data)
# Out:
#     Name  Age        city      salary
# 0   loki   19    new york    10000000
# 1  rawat   20  california    30000000
# 2  lucky   25       paris  5000000000

# %%
my_data = [
     ["loki",19,"new york"],
     ["rawat",20,"california"],
     ["lucky",25,"paris"],
     
]
def2 = pd.DataFrame(my_data)
columns = ["name","age","city"]
def2 = pd.DataFrame(my_data,columns = columns)
def2
# Out:
#     name age        city
# 0   loki  19    new york
# 1  rawat  20  california
# 2  lucky  25       paris

# %% [markdown]
# Selection And Indexing Of Column

# %%
def2
# Out:
#     name age        city
# 0   loki  19    new york
# 1  rawat  20  california
# 2  lucky  25       paris

# %%
def2['name']
# Out:
# 0     loki
# 1    rawat
# 2    lucky
# Name: name, dtype: object

# %%
def2[["name","city"]]
# Out:
#     name        city
# 0   loki    new york
# 1  rawat  california
# 2  lucky       paris

# %% [markdown]
# Creating A New Column

# %%
def2["designation"] = ["engineer","footballer","rich"]
def2
# Out:
#     name age        city designation
# 0   loki  19    new york    engineer
# 1  rawat  20  california  footballer
# 2  lucky  25       paris        rich

# %% [markdown]
# Removing a column

# %%
def2.drop('designation',axis = 1)
# Out:
#     name age        city
# 0   loki  19    new york
# 1  rawat  20  california
# 2  lucky  25       paris

# %%
def2
# Out:
#     name age        city designation
# 0   loki  19    new york    engineer
# 1  rawat  20  california  footballer
# 2  lucky  25       paris        rich

# %%
def2.drop('designation',axis=1,inplace = True)

# %%
def2
# Out:
#     name age        city
# 0   loki  19    new york
# 1  rawat  20  california
# 2  lucky  25       paris

# %% [markdown]
# Selecting A Row

# %%
def2.loc[0]
# Out:
# name        loki
# age           19
# city    new york
# Name: 0, dtype: object

# %%
def2.loc[[0,1]]
# Out:
#     name age        city
# 0   loki  19    new york
# 1  rawat  20  california

# %% [markdown]
# Selecting Subset Of Rows And Columns

# %%
def2.loc[[0,1]]
# Out:
#     name age        city
# 0   loki  19    new york
# 1  rawat  20  california

# %%
def2.loc[[0,1]][["age","city"]]
# Out:
#   age        city
# 0  19    new york
# 1  20  california

# %% [markdown]
# Condition Statement

# %%
def2
# Out:
#     name age        city
# 0   loki  19    new york
# 1  rawat  20  california
# 2  lucky  25       paris

# %%
def2['age'] = pd.to_numeric(def2['age'], errors='coerce')  # Convert to numeric, invalid values become NaN
def2[def2['age'] > 19]  # Now we can compare numeric values
# Out:
#     name  age        city
# 1  rawat   20  california
# 2  lucky   25       paris

# %%
def2[(def2['age'] > 19) & (def2['city'] == 'paris')]
# Out:
#     name  age   city
# 2  lucky   25  paris
